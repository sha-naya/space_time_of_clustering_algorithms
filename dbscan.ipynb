# %% [markdown]
# # DBSCAN
# ### Imports, RAM check, and data generation

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# !pip install memory-profiler
# %load_ext memory_profiler

from sklearn.cluster import DBSCAN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def create_exp1_data(
    n_samples_array: list, 
    n_features: int = 3, 
    centers: int = 5, 
    random_state: int = 17,
    ):
    global_storage: dict = {}
    for n_sample in n_samples_array:
        local_storage: dict = {}
        X, labels_true = make_blobs(
            n_samples=n_sample, 
            n_features=n_features,
            centers=centers, 
            random_state=random_state, 
        )
        X_scaled = StandardScaler().fit_transform(X)
        local_storage['X'], local_storage['X_scaled'], local_storage['labels_true'] = X, X_scaled, labels_true
        global_storage[n_sample] = local_storage
    return global_storage

exp1_n_features = 3
exp1_centers = 5
exp1_random_state = 17
exp1_n_samples_array: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
    2_000_000, 
    3_000_000,
]

exp1_data: dict = create_exp1_data(n_samples_array=exp1_n_samples_array)

# %% [markdown]
# ## Algorithm run
# #### n = 100

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[100]['X_scaled'])
# Out:
# peak memory: 634.18 MiB, increment: 0.05 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[100]['X_scaled'])
# Out:
# 908 µs ± 7.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# #### n = 500

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[500]['X_scaled'])
# Out:
# peak memory: 637.83 MiB, increment: 0.03 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[500]['X_scaled'])
# Out:
# 3.59 ms ± 19 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 1_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[1_000]['X_scaled'])
# Out:
# peak memory: 637.84 MiB, increment: 0.00 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[1_000]['X_scaled'])
# Out:
# 10.2 ms ± 25.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 3_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[3_000]['X_scaled'])
# Out:
# peak memory: 638.01 MiB, increment: 0.16 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[3_000]['X_scaled'])
# Out:
# 55.6 ms ± 421 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 5_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[5_000]['X_scaled'])
# Out:
# peak memory: 638.06 MiB, increment: 0.03 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[5_000]['X_scaled'])
# Out:
# 142 ms ± 432 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 7_500

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[7_500]['X_scaled'])
# Out:
# peak memory: 651.02 MiB, increment: 12.96 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[7_500]['X_scaled'])
# Out:
# 259 ms ± 1.89 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 10_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[10_000]['X_scaled'])
# Out:
# peak memory: 712.88 MiB, increment: 61.86 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[10_000]['X_scaled'])
# Out:
# 493 ms ± 3.98 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 15_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[15_000]['X_scaled'])
# Out:
# peak memory: 968.23 MiB, increment: 255.19 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[15_000]['X_scaled'])
# Out:
# 950 ms ± 4.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 20_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[20_000]['X_scaled'])
# Out:
# peak memory: 1139.21 MiB, increment: 170.70 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[20_000]['X_scaled'])
# Out:
# 1.73 s ± 8.55 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 50_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[50_000]['X_scaled'])
# Out:
# peak memory: 4475.24 MiB, increment: 3336.34 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[50_000]['X_scaled'])
# Out:
# 8.93 s ± 66 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 75_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[75_000]['X_scaled'])
# Out:
# peak memory: 9135.30 MiB, increment: 3581.86 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[75_000]['X_scaled'])
# Out:
# 20 s ± 177 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 100_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[100_000]['X_scaled'])
# Out:
# peak memory: 16123.83 MiB, increment: 6808.06 MiB

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[100_000]['X_scaled'])
# Out:
# 32.4 s ± 944 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 500_000

# %%
# %memit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[500_000]['X_scaled']) # died

# %%
# %timeit dbscan = DBSCAN(eps=0.5, min_samples=5).fit(exp1_data[500_000]['X_scaled'])
# Out:
# 3.18 s ± 193 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
