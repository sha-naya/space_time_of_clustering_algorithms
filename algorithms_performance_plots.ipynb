# %%
import pandas as pd
import seaborn as sns

# %%
k_means_memory_consumption: list = [
    625.36, 
    625.50, 
    636.46, 
    636.61, 
    636.72, 
    636.80, 
    636.80, 
    636.86,
    636.87,
    636.90,
    637.26,
    637.27,
    637.29,
    690.25,
    ]
k_means_time_consumption: list = [
    18.3,
    27.7,
    25,
    258,
    1560,
    1480,
    1480,
    1520,
    1720,
    1930,
    1820,
    1830,
    3180,
    4400,
]

k_means_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
]

len(k_means_memory_consumption) == len(k_means_sample_sizes) == len(k_means_time_consumption)
# Out:
# True

# %%
k_means_frame = pd.DataFrame(
    data={
        'memory_consumption': k_means_memory_consumption, 
        'sample_size': k_means_sample_sizes, 
        'algorithm': 'k_means',
        }
    )
k_means_frame.head()
# Out:
#    memory_consumption  sample_size algorithm
# 0              625.36          100   k_means
# 1              625.50          500   k_means
# 2              636.46         1000   k_means
# 3              636.61         3000   k_means
# 4              636.72         5000   k_means

# %%
k_means_timeframe = pd.DataFrame(
    data={
        'time_consumption': k_means_time_consumption, 
        'sample_size': k_means_sample_sizes, 
        'algorithm': 'k_means',
        }
    )
k_means_timeframe.head()
# Out:
#    time_consumption  sample_size algorithm
# 0              18.3          100   k_means
# 1              27.7          500   k_means
# 2              25.0         1000   k_means
# 3             258.0         3000   k_means
# 4            1560.0         5000   k_means

# %%
agglomerative_memory_consumption: list = [
    637.10,
    663.24,
    663.39,
    696.92,
    888.28,
    1318.34,
    1700.64,
    3037.07,
    4373.69,
    21605.90,
    50240.26,
]
agglomerative_time_consumption: list = [
    0.611,
    6,
    24.5,
    271,
    807,
    2160,
    4040,
    9320,
    18800,
    159000,
    569000,
]

agglomerative_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
]

len(agglomerative_memory_consumption) == len(agglomerative_sample_sizes) == len(agglomerative_time_consumption)
# Out:
# True

# %%
agglomerative_frame = pd.DataFrame(
    data={
        'memory_consumption': agglomerative_memory_consumption, 
        'sample_size': agglomerative_sample_sizes, 
        'algorithm': 'agglomerative_clustering',
        }
    )
agglomerative_frame.head()
# Out:
#    memory_consumption  sample_size                 algorithm
# 0              637.10          100  agglomerative_clustering
# 1              663.24          500  agglomerative_clustering
# 2              663.39         1000  agglomerative_clustering
# 3              696.92         3000  agglomerative_clustering
# 4              888.28         5000  agglomerative_clustering

# %%
agglomerative_timeframe = pd.DataFrame(
    data={
        'time_consumption': agglomerative_time_consumption, 
        'sample_size': agglomerative_sample_sizes, 
        'algorithm': 'agglomerative_clustering',
        }
    )
agglomerative_timeframe.head()
# Out:
#    time_consumption  sample_size                 algorithm
# 0             0.611          100  agglomerative_clustering
# 1             6.000          500  agglomerative_clustering
# 2            24.500         1000  agglomerative_clustering
# 3           271.000         3000  agglomerative_clustering
# 4           807.000         5000  agglomerative_clustering

# %%
spectral_memory_consumption: list = [
    632.07,
    634.98,
    648.01,
    930.61,
    1494.14,
    2645.81,
    4417.12,
    9223.25,
    16679.49,
]
spectral_time_consumption: list = [
    179,
    225,
    270,
    2370,
    4240,
    8550,
    16000,
    41600,
    88000,
]

spectral_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
]

len(spectral_memory_consumption) == len(spectral_sample_sizes) == len(spectral_time_consumption)
# Out:
# True

# %%
spectral_frame = pd.DataFrame(
    data={
        'memory_consumption': spectral_memory_consumption, 
        'sample_size': spectral_sample_sizes, 
        'algorithm': 'spectral_clustering',
        }
    )
spectral_frame.head()
# Out:
#    memory_consumption  sample_size            algorithm
# 0              632.07          100  spectral_clustering
# 1              634.98          500  spectral_clustering
# 2              648.01         1000  spectral_clustering
# 3              930.61         3000  spectral_clustering
# 4             1494.14         5000  spectral_clustering

# %%
spectral_timeframe = pd.DataFrame(
    data={
        'time_consumption': spectral_time_consumption, 
        'sample_size': spectral_sample_sizes, 
        'algorithm': 'spectral_clustering',
        }
    )
spectral_timeframe.head()
# Out:
#    time_consumption  sample_size            algorithm
# 0               179          100  spectral_clustering
# 1               225          500  spectral_clustering
# 2               270         1000  spectral_clustering
# 3              2370         3000  spectral_clustering
# 4              4240         5000  spectral_clustering

# %%
birch_memory_consumption: list = [
    630.07,
    630.99,
    641.72,
    642.21,
    642.24,
    642.30,
    642.32,
    642.37,
    642.70,
    643.57,
    644.69,
    839.77,
    843.21,
    844.86,
]
birch_time_consumption: list = [
    2.35,
    8.89,
    16.7,
    47.8,
    79.8,
    118,
    157,
    235,
    368,
    836,
    1220,
    1570,
    7610,
    15200,
]

birch_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
]

len(birch_memory_consumption) == len(birch_sample_sizes) == len(birch_time_consumption)
# Out:
# True

# %%
birch_frame = pd.DataFrame(
    data={
        'memory_consumption': birch_memory_consumption, 
        'sample_size': birch_sample_sizes, 
        'algorithm': 'birch',
        }
    )
birch_frame.head()
# Out:
#    memory_consumption  sample_size algorithm
# 0              630.07          100     birch
# 1              630.99          500     birch
# 2              641.72         1000     birch
# 3              642.21         3000     birch
# 4              642.24         5000     birch

# %%
birch_timeframe = pd.DataFrame(
    data={
        'time_consumption': birch_time_consumption, 
        'sample_size': birch_sample_sizes, 
        'algorithm': 'birch',
        }
    )
birch_timeframe.head()
# Out:
#    time_consumption  sample_size algorithm
# 0              2.35          100     birch
# 1              8.89          500     birch
# 2             16.70         1000     birch
# 3             47.80         3000     birch
# 4             79.80         5000     birch

# %%
dbscan_memory_consumption: list = [
    634.18,
    637.83,
    637.84,
    638.01,
    638.06,
    651.02,
    712.88,
    968.23,
    1139.21,
    4475.24,
    9135.30,
    16123.83,
]
dbscan_time_consumption: list = [
    0.908,
    3.59,
    10.2,
    55.6,
    142,
    259,
    493,
    950,
    1730,
    8930,
    20000,
    32400,
]

dbscan_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
]
len(dbscan_memory_consumption) == len(dbscan_sample_sizes) == len(dbscan_time_consumptin)
# Out:
# True

# %%
dbscan_frame = pd.DataFrame(
    data={
        'memory_consumption': dbscan_memory_consumption, 
        'sample_size': dbscan_sample_sizes, 
        'algorithm': 'dbscan',
        }
    )
dbscan_frame.head()
# Out:
#    memory_consumption  sample_size algorithm
# 0              634.18          100    dbscan
# 1              637.83          500    dbscan
# 2              637.84         1000    dbscan
# 3              638.01         3000    dbscan
# 4              638.06         5000    dbscan

# %%
dbscan_timeframe = pd.DataFrame(
    data={
        'time_consumption': dbscan_time_consumption, 
        'sample_size': dbscan_sample_sizes, 
        'algorithm': 'dbscan',
        }
    )
dbscan_timeframe.head()
# Out:
#    time_consumption  sample_size algorithm
# 0             0.908          100    dbscan
# 1             3.590          500    dbscan
# 2            10.200         1000    dbscan
# 3            55.600         3000    dbscan
# 4           142.000         5000    dbscan

# %%
hdbscan_memory_consumption: list = [
    630.31,
    641.76,
    641.98,
    642.89,
    643.43,
    644.09,
    644.75,
    645.43,
    646.28,
    654.41,
    661.91,
    691.69,
    1216.85,
    1347.02,
]
hdbscan_time_consumption: list = [
    2.47,
    9.32,
    18,
    58.7,
    110,
    182,
    263,
    434,
    531,
    1570,
    2630,
    3850,
    32700,
    101000,
]

hdbscan_sample_sizes: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
]

len(hdbscan_memory_consumption) == len(hdbscan_sample_sizes) == len(hdbscan_time_consumption)
# Out:
# True

# %%
hdbscan_frame = pd.DataFrame(
    data={
        'memory_consumption': hdbscan_memory_consumption, 
        'sample_size': hdbscan_sample_sizes, 
        'algorithm': 'hdbscan',
        }
    )
hdbscan_frame.head()
# Out:
#    memory_consumption  sample_size algorithm
# 0              630.31          100   hdbscan
# 1              641.76          500   hdbscan
# 2              641.98         1000   hdbscan
# 3              642.89         3000   hdbscan
# 4              643.43         5000   hdbscan

# %%
hdbscan_timeframe = pd.DataFrame(
    data={
        'time_consumption': hdbscan_time_consumption, 
        'sample_size': hdbscan_sample_sizes, 
        'algorithm': 'hdbscan',
        }
    )
hdbscan_timeframe.head()
# Out:
#    time_consumption  sample_size algorithm
# 0              2.47          100   hdbscan
# 1              9.32          500   hdbscan
# 2             18.00         1000   hdbscan
# 3             58.70         3000   hdbscan
# 4            110.00         5000   hdbscan

# %%
frames: list = [k_means_frame, agglomerative_frame, spectral_frame, birch_frame, dbscan_frame, hdbscan_frame]
algorithms_performance = pd.concat(objs=frames).reset_index(drop=True)
algorithms_performance.head()
# Out:
#    memory_consumption  sample_size algorithm
# 0              625.36          100   k_means
# 1              625.50          500   k_means
# 2              636.46         1000   k_means
# 3              636.61         3000   k_means
# 4              636.72         5000   k_means

# %%
frames_time: list = [k_means_timeframe, agglomerative_timeframe, spectral_timeframe, birch_timeframe, dbscan_timeframe, hdbscan_timeframe]
algorithms_performance_time = pd.concat(objs=frames_time).reset_index(drop=True)
algorithms_performance_time.head()
# Out:
#    time_consumption  sample_size algorithm
# 0              18.3          100   k_means
# 1              27.7          500   k_means
# 2              25.0         1000   k_means
# 3             258.0         3000   k_means
# 4            1560.0         5000   k_means

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=algorithms_performance, x='sample_size', y='memory_consumption', hue='algorithm')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data=algorithms_performance_time, x='sample_size', y='time_consumption', hue='algorithm')

# %%
algorithms_performance.pivot(index='algorithm', columns='sample_size', values='memory_consumption')
# Out:
# sample_size               100      500      1000     3000     5000     \
# algorithm
# agglomerative_clustering   637.10   663.24   663.39   696.92   888.28
# birch                      630.07   630.99   641.72   642.21   642.24
# dbscan                     634.18   637.83   637.84   638.01   638.06
# hdbscan                    630.31   641.76   641.98   642.89   643.43
# k_means                    625.36   625.50   636.46   636.61   636.72
# spectral_clustering        632.07   634.98   648.01   930.61  1494.14
#
# sample_size               7500     10000    15000     20000     50000    \
# algorithm
# agglomerative_clustering  1318.34  1700.64  3037.07   4373.69  21605.90
# birch                      642.30   642.32   642.37    642.70    643.57
# dbscan                     651.02   712.88   968.23   1139.21   4475.24
# hdbscan                    644.09   644.75   645.43    646.28    654.41
# k_means                    636.80   636.80   636.86    636.87    636.90
# ...

# %%
algorithms_performance_time.pivot(index='algorithm', columns='sample_size', values='time_consumption')
# Out:
# sample_size               100      500      1000     3000     5000     \
# algorithm
# agglomerative_clustering    0.611     6.00     24.5    271.0    807.0
# birch                       2.350     8.89     16.7     47.8     79.8
# dbscan                      0.908     3.59     10.2     55.6    142.0
# hdbscan                     2.470     9.32     18.0     58.7    110.0
# k_means                    18.300    27.70     25.0    258.0   1560.0
# spectral_clustering       179.000   225.00    270.0   2370.0   4240.0
#
# sample_size               7500     10000    15000    20000     50000    \
# algorithm
# agglomerative_clustering   2160.0   4040.0   9320.0  18800.0  159000.0
# birch                       118.0    157.0    235.0    368.0     836.0
# dbscan                      259.0    493.0    950.0   1730.0    8930.0
# hdbscan                     182.0    263.0    434.0    531.0    1570.0
# k_means                    1480.0   1480.0   1520.0   1720.0    1930.0
# ...

# %%
noise_lvls: list = [0.01, 0.05, 0.1, 0.15, 0.2]

k_means_rand: list = [0.7033165829145729, 0.7367336683417085, 0.795427135678392, 0.7298492462311558, 0.7097989949748744]
agglomerative_rand: list = [0.8166246246246246, 0.8393273273273273, 0.748966966966967, 0.8008888888888889, 0.7188408408408409]
spectral_rand: list = [0.7735735735735736, 0.7720940940940941, 0.7676796796796796, 0.7618498498498498, 0.7503823823823824]
birch_rand: list = [0.836036036036036, 0.7750570570570571, 0.7546526526526527, 0.7676796796796796, 0.6509009009009009]
dbscan_rand: list = [1, 1, 0.4994994994994995, 0.4994994994994995, 0.4994994994994995]
hdbscan_rand: list = [1, 1, 0.9772432432432433, 0.6973313313313313, 0.5086106106106106]

k_means_rand_frame = pd.DataFrame(
    data={
        'rand_score': k_means_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'k_means',
        }
    )
agglomerative_rand_frame = pd.DataFrame(
    data={
        'rand_score': agglomerative_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'agglomerative_clustering',
        }
    )
spectral_rand_frame = pd.DataFrame(
    data={
        'rand_score': spectral_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'spectral_clustering',
        }
    )
birch_rand_frame = pd.DataFrame(
    data={
        'rand_score': birch_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'birch',
        }
    )
dbscan_rand_frame = pd.DataFrame(
    data={
        'rand_score': dbscan_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'dbscan',
        }
    )
hdbscan_rand_frame = pd.DataFrame(
    data={
        'rand_score': hdbscan_rand, 
        'noise_lvl': noise_lvls, 
        'algorithm': 'hdbscan',
        }
    )

frames_rand: list = [
    k_means_rand_frame, 
    agglomerative_rand_frame, 
    spectral_rand_frame, 
    birch_rand_frame, 
    dbscan_rand_frame, 
    hdbscan_rand_frame,
    ]

algorithms_performance_rand = pd.concat(objs=frames_rand).reset_index(drop=True)
algorithms_performance_rand.head()
# Out:
#    rand_score  noise_lvl algorithm
# 0    0.703317       0.01   k_means
# 1    0.736734       0.05   k_means
# 2    0.795427       0.10   k_means
# 3    0.729849       0.15   k_means
# 4    0.709799       0.20   k_means

# %%
algorithms_performance_rand.pivot(index='algorithm', columns='noise_lvl', values='rand_score')
# Out:
# noise_lvl                     0.01      0.05      0.10      0.15      0.20
# algorithm
# agglomerative_clustering  0.816625  0.839327  0.748967  0.800889  0.718841
# birch                     0.836036  0.775057  0.754653  0.767680  0.650901
# dbscan                    1.000000  1.000000  0.499499  0.499499  0.499499
# hdbscan                   1.000000  1.000000  0.977243  0.697331  0.508611
# k_means                   0.703317  0.736734  0.795427  0.729849  0.709799
# spectral_clustering       0.773574  0.772094  0.767680  0.761850  0.750382

# %%
sd_value = [1, 1.5, 2, 2.5, 3]

k_means_rand2 = [0.9606030150753769, 1, 0.9415075376884422, 0.8353768844221106, 0.7367336683417085]
agglomerative_rand2 = [1, 0.996004004004004, 0.9782202202202203, 0.9286666666666666, 0.8543363363363363]
spectral_rand2 = [1, 0.9940120120120121, 0.9704204204204204, 0.9212832832832832, 0.8393273273273273]
birch_rand2 = [1, 0.5354474474474474, 0.5132912912912913, 0.6072552552552553, 0.5076996996996997]
dbscan_rand2 = [0.998, 0.4995015015015015, 0.4995075075075075, 0.4994994994994995, 0.4994994994994995]
hdbscan_rand2 = [0.9749869869869869, 0.957963963963964, 0.8741581581581581, 0.49975775775775777, 0.5457537537537538]

k_means_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': k_means_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'k_means',
        }
    )
agglomerative_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': agglomerative_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'agglomerative_clustering',
        }
    )
spectral_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': spectral_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'spectral_clustering',
        }
    )
birch_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': birch_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'birch',
        }
    )
dbscan_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': dbscan_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'dbscan',
        }
    )
hdbscan_rand_frame2 = pd.DataFrame(
    data={
        'rand_score': hdbscan_rand2, 
        'sd_value': sd_value, 
        'algorithm': 'hdbscan',
        }
    )

frames_rand2: list = [
    k_means_rand_frame2, 
    agglomerative_rand_frame2, 
    spectral_rand_frame2, 
    birch_rand_frame2, 
    dbscan_rand_frame2, 
    hdbscan_rand_frame2,
    ]

algorithms_performance_rand2 = pd.concat(objs=frames_rand2).reset_index(drop=True)
algorithms_performance_rand2.head()
# Out:
#    rand_score  sd_value algorithm
# 0    0.960603       1.0   k_means
# 1    1.000000       1.5   k_means
# 2    0.941508       2.0   k_means
# 3    0.835377       2.5   k_means
# 4    0.736734       3.0   k_means

# %%
algorithms_performance_rand2.pivot(index='algorithm', columns='sd_value', values='rand_score')
# Out:
# sd_value                       1.0       1.5       2.0       2.5       3.0
# algorithm
# agglomerative_clustering  1.000000  0.996004  0.978220  0.928667  0.854336
# birch                     1.000000  0.535447  0.513291  0.607255  0.507700
# dbscan                    0.998000  0.499502  0.499508  0.499499  0.499499
# hdbscan                   0.974987  0.957964  0.874158  0.499758  0.545754
# k_means                   0.960603  1.000000  0.941508  0.835377  0.736734
# spectral_clustering       1.000000  0.994012  0.970420  0.921283  0.839327
