# %% [markdown]
# # OPTICS
# ### Imports, RAM check, and data generation

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# !pip install memory-profiler
# %load_ext memory_profiler

from sklearn.cluster import OPTICS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def create_exp1_data(
    n_samples_array: list, 
    n_features: int = 3, 
    centers: int = 5, 
    random_state: int = 17,
    ):
    global_storage: dict = {}
    for n_sample in n_samples_array:
        local_storage: dict = {}
        X, labels_true = make_blobs(
            n_samples=n_sample, 
            n_features=n_features,
            centers=centers, 
            random_state=random_state, 
        )
        X_scaled = StandardScaler().fit_transform(X)
        local_storage['X'], local_storage['X_scaled'], local_storage['labels_true'] = X, X_scaled, labels_true
        global_storage[n_sample] = local_storage
    return global_storage

exp1_n_features = 3
exp1_centers = 5
exp1_random_state = 17
exp1_n_samples_array: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
]

exp1_data: dict = create_exp1_data(n_samples_array=exp1_n_samples_array)

# %% [markdown]
# ## Algorithm run
# #### n = 100

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[100]['X_scaled'])
# Out:
# peak memory: 319.66 MiB, increment: 0.37 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[100]['X_scaled'])
# Out:
# 68.6 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 500

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[500]['X_scaled'])
# Out:
# peak memory: 323.18 MiB, increment: 0.04 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[500]['X_scaled'])
# Out:
# 373 ms ± 6.31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 1_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[1_000]['X_scaled'])
# Out:
# peak memory: 323.18 MiB, increment: 0.00 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[1_000]['X_scaled'])
# Out:
# 798 ms ± 13.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 3_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[3_000]['X_scaled'])
# Out:
# peak memory: 324.04 MiB, increment: 0.47 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[3_000]['X_scaled'])
# Out:
# 2.57 s ± 13.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 5_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[5_000]['X_scaled'])
# Out:
# peak memory: 329.32 MiB, increment: 0.06 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[5_000]['X_scaled'])
# Out:
# 4.72 s ± 43.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 7_500

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[7_500]['X_scaled'])
# Out:
# peak memory: 334.94 MiB, increment: 0.05 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[7_500]['X_scaled'])
# Out:
# 7.78 s ± 34.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 10_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[10_000]['X_scaled'])
# Out:
# peak memory: 344.23 MiB, increment: 0.05 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[10_000]['X_scaled'])
# Out:
# 11.3 s ± 43.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 15_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[15_000]['X_scaled'])
# Out:
# peak memory: 360.61 MiB, increment: 0.00 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[15_000]['X_scaled'])
# Out:
# 20.3 s ± 150 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 20_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[20_000]['X_scaled'])
# Out:
# peak memory: 388.84 MiB, increment: 0.00 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[20_000]['X_scaled'])
# Out:
# 31.9 s ± 454 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 50_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[50_000]['X_scaled'])
# Out:
# peak memory: 424.37 MiB, increment: 5.25 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[50_000]['X_scaled'])
# Out:
# 2min 47s ± 1.93 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 75_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[75_000]['X_scaled'])
# Out:
# peak memory: 588.18 MiB, increment: 7.79 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[75_000]['X_scaled'])
# Out:
# 5min 54s ± 4.57 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 100_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[100_000]['X_scaled'])
# Out:
# peak memory: 739.04 MiB, increment: 3.87 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[100_000]['X_scaled'])
# Out:
# 10min 43s ± 5.16 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 500_000

# %%
# %memit birch = optics = OPTICS(min_samples=5).fit(exp1_data[500_000]['X_scaled'])
# Out:
# peak memory: 392.72 MiB, increment: 85.26 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[500_000]['X_scaled'])
# Out:
# 7.61 s ± 28.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 1_000_000

# %%
# %memit optics = OPTICS(min_samples=5).fit(exp1_data[1_000_000]['X_scaled'])
# Out:
# peak memory: 844.86 MiB, increment: 1.66 MiB

# %%
# %timeit optics = OPTICS(min_samples=5).fit(exp1_data[1_000_000]['X_scaled'])
# Out:
# 15.2 s ± 77.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
