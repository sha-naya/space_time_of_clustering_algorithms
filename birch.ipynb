# %% [markdown]
# # Birch
# ### Imports, RAM check, and data generation

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# !pip install memory-profiler
# %load_ext memory_profiler

from sklearn.cluster import Birch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def create_exp1_data(
    n_samples_array: list, 
    n_features: int = 3, 
    centers: int = 5, 
    random_state: int = 17,
    ):
    global_storage: dict = {}
    for n_sample in n_samples_array:
        local_storage: dict = {}
        X, labels_true = make_blobs(
            n_samples=n_sample, 
            n_features=n_features,
            centers=centers, 
            random_state=random_state, 
        )
        X_scaled = StandardScaler().fit_transform(X)
        local_storage['X'], local_storage['X_scaled'], local_storage['labels_true'] = X, X_scaled, labels_true
        global_storage[n_sample] = local_storage
    return global_storage

exp1_n_features = 3
exp1_centers = 5
exp1_random_state = 17
exp1_n_samples_array: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000,
    500_000, 
    1_000_000, 
    2_000_000, 
]

exp1_data: dict = create_exp1_data(n_samples_array=exp1_n_samples_array)

# %% [markdown]
# ## Algorithm run
# #### n = 100

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[100]['X_scaled'])
# Out:
# peak memory: 630.07 MiB, increment: 1.17 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[100]['X_scaled'])
# Out:
# 2.35 ms ± 28.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 500

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[500]['X_scaled'])
# Out:
# peak memory: 630.99 MiB, increment: 0.07 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[500]['X_scaled'])
# Out:
# 8.89 ms ± 151 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 1_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[1_000]['X_scaled'])
# Out:
# peak memory: 641.72 MiB, increment: 0.00 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[1_000]['X_scaled'])
# Out:
# 16.7 ms ± 163 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 3_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[3_000]['X_scaled'])
# Out:
# peak memory: 642.21 MiB, increment: 0.06 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[3_000]['X_scaled'])
# Out:
# 47.8 ms ± 329 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 5_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[5_000]['X_scaled'])
# Out:
# peak memory: 642.24 MiB, increment: 0.00 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[5_000]['X_scaled'])
# Out:
# 79.8 ms ± 1.11 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 7_500

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[7_500]['X_scaled'])
# Out:
# peak memory: 642.30 MiB, increment: 0.03 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[7_500]['X_scaled'])
# Out:
# 118 ms ± 1.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 10_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[10_000]['X_scaled'])
# Out:
# peak memory: 642.32 MiB, increment: 0.00 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[10_000]['X_scaled'])
# Out:
# 157 ms ± 1.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 15_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[15_000]['X_scaled'])
# Out:
# peak memory: 642.37 MiB, increment: 0.00 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[15_000]['X_scaled'])
# Out:
# 235 ms ± 4.45 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 20_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[20_000]['X_scaled'])
# Out:
# peak memory: 642.70 MiB, increment: 0.32 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[20_000]['X_scaled'])
# Out:
# 368 ms ± 7.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 50_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[50_000]['X_scaled'])
# Out:
# peak memory: 643.57 MiB, increment: 0.87 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[50_000]['X_scaled'])
# Out:
# 836 ms ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 75_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[75_000]['X_scaled'])
# Out:
# peak memory: 644.69 MiB, increment: 1.07 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[75_000]['X_scaled'])
# Out:
# 1.22 s ± 7.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 100_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[100_000]['X_scaled'])
# Out:
# peak memory: 839.77 MiB, increment: 2.33 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[100_000]['X_scaled'])
# Out:
# 1.57 s ± 21.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 500_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[500_000]['X_scaled'])
# Out:
# peak memory: 843.21 MiB, increment: 3.30 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[500_000]['X_scaled'])
# Out:
# 7.61 s ± 28.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 1_000_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[1_000_000]['X_scaled'])
# Out:
# peak memory: 844.86 MiB, increment: 1.66 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[1_000_000]['X_scaled'])
# Out:
# 15.2 s ± 77.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 2_000_000

# %%
# %memit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[2_000_000]['X_scaled'])
# Out:
# peak memory: 845.80 MiB, increment: 0.93 MiB

# %%
# %timeit birch = Birch(threshold=0.5, branching_factor=50, n_clusters=exp1_centers).fit(exp1_data[2_000_000]['X_scaled'])
# Out:
# 30.2 s ± 91.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
