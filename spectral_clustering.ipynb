# %% [markdown]
# # Spectral Clustering
# ### Imports, RAM check, and data generation

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# !pip install memory-profiler
# %load_ext memory_profiler

from sklearn.cluster import SpectralClustering
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def create_exp1_data(
    n_samples_array: list, 
    n_features: int = 3, 
    centers: int = 5, 
    random_state: int = 17,
    ):
    global_storage: dict = {}
    for n_sample in n_samples_array:
        local_storage: dict = {}
        X, labels_true = make_blobs(
            n_samples=n_sample, 
            n_features=n_features,
            centers=centers, 
            random_state=random_state, 
        )
        X_scaled = StandardScaler().fit_transform(X)
        local_storage['X'], local_storage['X_scaled'], local_storage['labels_true'] = X, X_scaled, labels_true
        global_storage[n_sample] = local_storage
    return global_storage

exp1_n_features = 3
exp1_centers = 5
exp1_random_state = 17
exp1_n_samples_array: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000, 
    1_000_000, 
    2_000_000, 
    3_000_000,
]

exp1_data: dict = create_exp1_data(n_samples_array=exp1_n_samples_array)

# %% [markdown]
# ## Algorithm run
# #### n = 100

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[100]['X_scaled'])
# Out:
# peak memory: 632.07 MiB, increment: 2.42 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[100]['X_scaled'])
# Out:
# 179 ms ± 48.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 500

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[500]['X_scaled'])
# Out:
# peak memory: 634.98 MiB, increment: 1.87 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[500]['X_scaled'])
# Out:
# 225 ms ± 30.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 1_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[1_000]['X_scaled'])
# Out:
# peak memory: 648.01 MiB, increment: 2.14 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[1_000]['X_scaled'])
# Out:
# 270 ms ± 8.78 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 3_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[3_000]['X_scaled'])
# Out:
# peak memory: 930.61 MiB, increment: 282.54 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[3_000]['X_scaled'])
# Out:
# 2.37 s ± 224 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 5_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[5_000]['X_scaled'])
# Out:
# peak memory: 1494.14 MiB, increment: 494.75 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[5_000]['X_scaled'])
# Out:
# 4.24 s ± 513 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 7_500

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[7_500]['X_scaled'])
# Out:
# peak memory: 2645.81 MiB, increment: 960.75 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[7_500]['X_scaled'])
# Out:
# 8.55 s ± 414 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 10_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[10_000]['X_scaled'])
# Out:
# peak memory: 4417.12 MiB, increment: 1341.72 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[10_000]['X_scaled'])
# Out:
# 16 s ± 622 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 15_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[15_000]['X_scaled'])
# Out:
# peak memory: 9223.25 MiB, increment: 4042.40 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[15_000]['X_scaled'])
# Out:
# 41.6 s ± 391 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 20_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[20_000]['X_scaled'])
# Out:
# peak memory: 16679.49 MiB, increment: 5737.96 MiB

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[20_000]['X_scaled'])
# Out:
# 1min 28s ± 1.16 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 50_000

# %%
# %memit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[50_000]['X_scaled']) # died here

# %%
# %timeit spectral = SpectralClustering(n_clusters=exp1_centers, assign_labels='kmeans', random_state=exp1_random_state,).fit(exp1_data[50_000]['X_scaled'])
# Out:
# 2min 39s ± 29.5 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
