# %% [markdown]
# # Agglomerative Clustering
# ### Imports, RAM check, and data generation

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# !pip install memory-profiler
# %load_ext memory_profiler

from sklearn.cluster import AgglomerativeClustering
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def create_exp1_data(
    n_samples_array: list, 
    n_features: int = 3, 
    centers: int = 5, 
    random_state: int = 17,
    ):
    global_storage: dict = {}
    for n_sample in n_samples_array:
        local_storage: dict = {}
        X, labels_true = make_blobs(
            n_samples=n_sample, 
            n_features=n_features,
            centers=centers, 
            random_state=random_state, 
        )
        X_scaled = StandardScaler().fit_transform(X)
        local_storage['X'], local_storage['X_scaled'], local_storage['labels_true'] = X, X_scaled, labels_true
        global_storage[n_sample] = local_storage
    return global_storage

exp1_n_features = 3
exp1_centers = 5
exp1_random_state = 17
exp1_n_samples_array: list = [
    100,
    500, 
    1_000,
    3_000, 
    5_000,
    7_500, 
    10_000,
    15_000, 
    20_000, 
    50_000,
    75_000, 
    100_000, 
    1_000_000, 
    2_000_000, 
    3_000_000,
]

exp1_data: dict = create_exp1_data(n_samples_array=exp1_n_samples_array)

# %% [markdown]
# ## Algorithm run
# #### n = 100

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[100]['X_scaled'])
# Out:
# peak memory: 637.10 MiB, increment: 0.77 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[100]['X_scaled'])
# Out:
# 611 µs ± 4.03 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# #### n = 500

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[500]['X_scaled'])
# Out:
# peak memory: 663.24 MiB, increment: 0.95 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[500]['X_scaled'])
# Out:
# 6 ms ± 44 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### n = 1_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[1_000]['X_scaled'])
# Out:
# peak memory: 663.39 MiB, increment: 0.00 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[1_000]['X_scaled'])
# Out:
# 24.5 ms ± 276 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### n = 3_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[3_000]['X_scaled'])
# Out:
# peak memory: 696.92 MiB, increment: 33.52 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[3_000]['X_scaled'])
# Out:
# 271 ms ± 4.82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 5_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[5_000]['X_scaled'])
# Out:
# peak memory: 888.28 MiB, increment: 191.24 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[5_000]['X_scaled'])
# Out:
# 807 ms ± 43.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 7_500

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[7_500]['X_scaled'])
# Out:
# peak memory: 1318.34 MiB, increment: 429.70 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[7_500]['X_scaled'])
# Out:
# 2.16 s ± 14.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 10_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[10_000]['X_scaled'])
# Out:
# peak memory: 1700.64 MiB, increment: 382.12 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[10_000]['X_scaled'])
# Out:
# 4.04 s ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 15_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[15_000]['X_scaled'])
# Out:
# peak memory: 3037.07 MiB, increment: 1336.43 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[15_000]['X_scaled'])
# Out:
# 9.32 s ± 425 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 20_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[20_000]['X_scaled'])
# Out:
# peak memory: 4373.69 MiB, increment: 1229.33 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[20_000]['X_scaled'])
# Out:
# 18.8 s ± 191 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 50_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[50_000]['X_scaled'])
# Out:
# peak memory: 21605.90 MiB, increment: 17232.21 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[50_000]['X_scaled'])
# Out:
# 2min 39s ± 29.5 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### n = 75_000

# %%
# %memit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[75_000]['X_scaled'])
# Out:
# peak memory: 50240.26 MiB, increment: 28979.44 MiB

# %%
# %timeit agglomerative = AgglomerativeClustering(n_clusters=exp1_centers).fit(exp1_data[75_000]['X_scaled'])
# Out:
# 9min 29s ± 42.3 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
